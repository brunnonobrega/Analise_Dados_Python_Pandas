# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/campeonato-brasileiro-full.csv",sep=";")

# %%
df["Data"]=pd.to_datetime(df["Data"])

# %%
df["Ano"]=df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         ID Rodada       Data  ... Estado Visitante Estado Vencedor   Ano
# 7443  7444     27 2018-09-30  ...               PE              MG  2018
# 4837  4838     32 2011-10-30  ...               RJ              RS  2011
# 6472  6473      6 2016-06-05  ...               MG               -  2016
# 7371  7372     20 2018-08-22  ...               RS              RS  2018
# 5024  5025     13 2012-07-29  ...               SP               -  2012
#
# [5 rows x 15 columns]

# %%
df1=df[['Mandante','Visitante','Vencedor','Estado Vencedor','Mandante Placar', 'Visitante Placar','Ano']]
df1=df1.rename(columns={'Estado Vencedor':'Estado_Vencedor','Mandante Placar':'Mandante_Placar', 'Visitante Placar':'Visitante_Placar'})
df1.sample(5)
# Out:
#          Mandante     Visitante  ... Visitante_Placar   Ano
# 5667     Criciúma     Palmeiras  ...                2  2014
# 3178    São Paulo  Athlético-PR  ...                0  2007
# 6821        Vasco    Fluminense  ...                2  2017
# 4066  Botafogo-RJ      Flamengo  ...                1  2009
# 6190  Corinthians         Vasco  ...                0  2015
#
# [5 rows x 7 columns]

# %%
df1.isnull().sum()
#df1.isna().sum()
#df.fillna(9999, inplace=True)
# Out:
# Mandante            0
# Visitante           0
# Vencedor            0
# Estado_Vencedor     0
# Mandante_Placar     0
# Visitante_Placar    0
# Ano                 0
# dtype: int64

# %%
df1.dtypes
# Out:
# Mandante            object
# Visitante           object
# Vencedor            object
# Estado_Vencedor     object
# Mandante_Placar      int64
# Visitante_Placar     int64
# Ano                  int64
# dtype: object

# %%
df1['Vencedor'].max()
# Out:
# 'são paulo'

# %%
df1['Estado_Vencedor'].max()
# Out:
# 'SP'

# %%
df1.nlargest(5,"Mandante_Placar")
# Out:
#        Mandante  Visitante   Vencedor  ... Mandante_Placar  Visitante_Placar   Ano
# 357       Vasco    Guarani      Vasco  ...               7                 1  2001
# 693       Vasco  São Paulo      Vasco  ...               7                 1  2001
# 1122      Goiás  Juventude      Goiás  ...               7                 0  2003
# 1671   Criciúma      Goiás   Criciúma  ...               7                 2  2004
# 1992  São Paulo   Paysandu  São Paulo  ...               7                 0  2004
#
# [5 rows x 7 columns]

# %%
vencedor=df1.loc[df1["Vencedor"]=="Ceará"]
vencedor
# Out:
#            Mandante      Visitante  ... Visitante_Placar   Ano
# 4145          Ceará     Fluminense  ...                0  2010
# 4167          Ceará       Cruzeiro  ...                0  2010
# 4168          Ceará        Vitória  ...                0  2010
# 4191          Ceará           Avaí  ...                0  2010
# 4205    Atlético-MG          Ceará  ...                1  2010
# 4279          Ceará         Grêmio  ...                1  2010
# 4344          Ceará         Santos  ...                1  2010
# 4410          Ceará  Internacional  ...                0  2010
# 4423          Ceará        Guarani  ...                0  2010
# 4445          Ceará      São Paulo  ...                0  2010
# 4531  Internacional          Ceará  ...                1  2011
# 4572          Ceará      Palmeiras  ...                0  2011
# 4589          Ceará    Atlético-MG  ...                0  2011
# 4612          Ceará     América-MG  ...                0  2011
# 4635          Ceará   Athlético-PR  ...                1  2011
# 4678          Ceará         Grêmio  ...                0  2011
# 4704          Ceará          Bahia  ...                0  2011
# 4772          Ceará       Coritiba  ...                2  2011
# 4844           Avaí          Ceará  ...                2  2011
# 4869         Grêmio          Ceará  ...                3  2011
# 7298          Ceará          Sport  ...                0  2018
# 7326          Ceará     Fluminense  ...                0  2018
# 7343         Paraná          Ceará  ...                1  2018
# 7394       Flamengo          Ceará  ...                1  2018
# 7401          Ceará    Corinthians  ...                1  2018
# 7419          Ceará        Vitória  ...                0  2018
# 7444          Ceará    Chapecoense  ...                1  2018
# 7478       Cruzeiro          Ceará  ...                2  2018
# 7488          Ceará    Atlético-MG  ...                1  2018
# 7536          Ceará         Paraná  ...                0  2018
# 7565          Ceará            CSA  ...                0  2019
# 7604          Ceará         Grêmio  ...                1  2019
# 7617           Avaí          Ceará  ...                2  2019
# 7661          Ceará      Palmeiras  ...                0  2019
# 7678          Ceará      Fortaleza  ...                1  2019
# 7689          Ceará    Chapecoense  ...                1  2019
# 7804          Ceará           Avaí  ...                0  2019
# 7828          Bahia          Ceará  ...                2  2019
# 7839          Ceará     Fluminense  ...                0  2019
# 7865          Ceará  Internacional  ...                0  2019
# 7987          Ceará          Bahia  ...                0  2020
# 7996    Atlético-GO          Ceará  ...                2  2020
# 7999          Ceará      Fortaleza  ...                0  2020
# 8035          Ceará       Flamengo  ...                0  2020
# 8088          Ceará    Corinthians  ...                1  2020
# 8111          Ceará       Coritiba  ...                1  2020
# 8166          Vasco          Ceará  ...                4  2020
# 8173          Bahia          Ceará  ...                2  2020
# 8197      Fortaleza          Ceará  ...                2  2020
# 8222       Flamengo          Ceará  ...                2  2021
# 8247          Goiás          Ceará  ...                4  2021
# 8253          Ceará      Palmeiras  ...                1  2021
# 8299       Coritiba          Ceará  ...                2  2021
# 8317          Ceará    Botafogo-RJ  ...                1  2021
# 8324          Ceará         grêmio  ...                2  2021
# 8372          Ceará    atlético-mg  ...                1  2021
# 8403          Ceará      juventude  ...                0  2021
# 8427          Ceará   athletico-pr  ...                0  2021
#
# [58 rows x 7 columns]

# %%
vencedor=df1.loc[df1["Vencedor"]=="Ceará",'Vencedor'].count()
vencedor
# Out:
# 58

# %%
vencedor=df1.loc[df1["Vencedor"]=="ceará",'Vencedor'].count()
vencedor
# Out:
# 0

# %%
#df1.loc[:,'Vencedor'].unique()
df1.loc[:,'Vencedor'].str.lower().unique()
# Out:
# array(['fluminense', 'sport', 'vitória', '-', 'athlético-pr', 'gama',
#        'goiás', 'bahia', 'flamengo', 'ponte preta', 'santos',
#        'corinthians', 'botafogo-rj', 'palmeiras', 'são paulo',
#        'santa cruz', 'vasco', 'internacional', 'portuguesa',
#        'atlético-mg', 'cruzeiro', 'coritiba', 'grêmio', 'juventude',
#        'américa-mg', 'guarani', 'paraná', 'são caetano', 'botafogo-sp',
#        'paysandu', 'figueirense', 'criciúma', 'fortaleza', 'brasiliense',
#        'américa-rn', 'náutico', 'ipatinga', 'santo andré', 'barueri',
#        'avaí', 'ceará', 'grêmio prudente', 'atlético-go', 'chapecoense',
#        'joinville', 'csa', 'bragantino', 'athletico-pr', 'cuiabá'],
#       dtype=object)

# %%
df1.loc[:,'Estado_Vencedor'].unique()
# Out:
# array(['RJ', 'PE', 'ES', '-', 'PR', 'DF', 'GO', 'BA', 'SP', 'RS', 'MG',
#        'PA', 'SC', 'CE', 'RN', 'AL', 'MT'], dtype=object)

# %%
filtro = df1.Vencedor=='Ceará'
#filtro1 = df1.Ano=="2018"
df2=df1.loc[filtro]
df2
#df1.loc[filtro|filtro1]
#df1.loc[filtro].groupby['Ano']
# Out:
#            Mandante      Visitante  ... Visitante_Placar   Ano
# 4145          Ceará     Fluminense  ...                0  2010
# 4167          Ceará       Cruzeiro  ...                0  2010
# 4168          Ceará        Vitória  ...                0  2010
# 4191          Ceará           Avaí  ...                0  2010
# 4205    Atlético-MG          Ceará  ...                1  2010
# 4279          Ceará         Grêmio  ...                1  2010
# 4344          Ceará         Santos  ...                1  2010
# 4410          Ceará  Internacional  ...                0  2010
# 4423          Ceará        Guarani  ...                0  2010
# 4445          Ceará      São Paulo  ...                0  2010
# 4531  Internacional          Ceará  ...                1  2011
# 4572          Ceará      Palmeiras  ...                0  2011
# 4589          Ceará    Atlético-MG  ...                0  2011
# 4612          Ceará     América-MG  ...                0  2011
# 4635          Ceará   Athlético-PR  ...                1  2011
# 4678          Ceará         Grêmio  ...                0  2011
# 4704          Ceará          Bahia  ...                0  2011
# 4772          Ceará       Coritiba  ...                2  2011
# 4844           Avaí          Ceará  ...                2  2011
# 4869         Grêmio          Ceará  ...                3  2011
# 7298          Ceará          Sport  ...                0  2018
# 7326          Ceará     Fluminense  ...                0  2018
# 7343         Paraná          Ceará  ...                1  2018
# 7394       Flamengo          Ceará  ...                1  2018
# 7401          Ceará    Corinthians  ...                1  2018
# 7419          Ceará        Vitória  ...                0  2018
# 7444          Ceará    Chapecoense  ...                1  2018
# 7478       Cruzeiro          Ceará  ...                2  2018
# 7488          Ceará    Atlético-MG  ...                1  2018
# 7536          Ceará         Paraná  ...                0  2018
# 7565          Ceará            CSA  ...                0  2019
# 7604          Ceará         Grêmio  ...                1  2019
# 7617           Avaí          Ceará  ...                2  2019
# 7661          Ceará      Palmeiras  ...                0  2019
# 7678          Ceará      Fortaleza  ...                1  2019
# 7689          Ceará    Chapecoense  ...                1  2019
# 7804          Ceará           Avaí  ...                0  2019
# 7828          Bahia          Ceará  ...                2  2019
# 7839          Ceará     Fluminense  ...                0  2019
# 7865          Ceará  Internacional  ...                0  2019
# 7987          Ceará          Bahia  ...                0  2020
# 7996    Atlético-GO          Ceará  ...                2  2020
# 7999          Ceará      Fortaleza  ...                0  2020
# 8035          Ceará       Flamengo  ...                0  2020
# 8088          Ceará    Corinthians  ...                1  2020
# 8111          Ceará       Coritiba  ...                1  2020
# 8166          Vasco          Ceará  ...                4  2020
# 8173          Bahia          Ceará  ...                2  2020
# 8197      Fortaleza          Ceará  ...                2  2020
# 8222       Flamengo          Ceará  ...                2  2021
# 8247          Goiás          Ceará  ...                4  2021
# 8253          Ceará      Palmeiras  ...                1  2021
# 8299       Coritiba          Ceará  ...                2  2021
# 8317          Ceará    Botafogo-RJ  ...                1  2021
# 8324          Ceará         grêmio  ...                2  2021
# 8372          Ceará    atlético-mg  ...                1  2021
# 8403          Ceará      juventude  ...                0  2021
# 8427          Ceará   athletico-pr  ...                0  2021
#
# [58 rows x 7 columns]

# %%
#df2=df2.columns.str.lower()
#ceara_2020=df2.loc[(df2['Vencedor']=="ceará")&(df2["Ano"]==2020)]
#ceara_2020['Vencedor'].count()

# %%
ceara_2020=df2.loc[(df2['Vencedor']=="Ceará")&(df2["Ano"]==2020) ]
ceara_2020['Vencedor'].count()
#ceara_2020
# Out:
# 9

# %%
ceara_2019=df2.loc[(df2['Vencedor']=="Ceará")&(df2["Ano"]==2019) ]
ceara_2019['Vencedor'].count()
# Out:
# 10

# %%
ceara_2018=df2.loc[(df2['Vencedor']=="Ceará")&(df2["Ano"]==2018) ]
ceara_2018['Vencedor'].count()
# Out:
# 10

# %%
ceara_2011=df2.loc[(df2['Vencedor']=="Ceará")&(df2["Ano"]==2011) ]
ceara_2011['Vencedor'].count()
# Out:
# 10

# %%
ceara_2010=df2.loc[(df2['Vencedor']=="Ceará")&(df2["Ano"]==2010) ]
ceara_2010['Vencedor'].count()
# Out:
# 10

# %%
#ceara_2021=df2.loc[(df2['Vencedor']=="Ceará")&(df2["Ano"]==2021) ]
#ceara_2021['Vencedor'].count()

# %%
vit_5_anos_1div = pd.DataFrame({"Ano":["2020", "2019", "2018", "2011","2010"],"Vitórias": [9, 10, 10, 10, 10]})
vit_5_anos_1div
# Out:
#     Ano  Vitórias
# 0  2020         9
# 1  2019        10
# 2  2018        10
# 3  2011        10
# 4  2010        10

# %%
#df.set_index('Ano')
#df.reset_index(drop=True, inplace=True)
import matplotlib.pyplot as plt

vit_5_anos_1div.set_index('Ano', inplace=True)
vit_5_anos_1div.plot.bar(title="Num Vitórias do Ceará na Série A do Brasileirão");
plt.ylabel('Total vitórias')
#plt.xlabel=('Ano')
# Out:
# Text(0, 0.5, 'Total vitórias')
